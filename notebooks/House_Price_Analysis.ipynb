# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("../data/house_price_dataset.csv")

# Display the first 5 rows
df.head()
# Out:
#    Property_ID       City    Locality Property_Type  BHK  Bathroom  Balcony  \
# 0       100001  Hyderabad    Madhapur     Apartment    2       1.0      2.0
# 1       100002       Pune       Baner     Apartment    1       1.0      0.0
# 2       100003  Bangalore   Yelahanka     Apartment    2       2.0      0.0
# 3       100004    Chennai  Anna Nagar     Apartment    3       2.0      2.0
# 4       100005     Mumbai     Andheri     Apartment    4       4.0      2.0
#
#    Floor_No  Total_Floors  Total_Area_in_Sqft  ...      Furnishing  \
# 0         3            26                 938  ...     Unfurnished
# 1        18            28                 546  ...       Furnished
# 2        17            18                1224  ...  Semi-Furnished
# 3        16            34                1759  ...  Semi-Furnished
# 4        22            25                1997  ...     Unfurnished
#
#     Transaction Property_Age Facing  Lift  Gym Power_Backup Gated_Community  \
# ...

# %%
df.shape
# Out:
# (50500, 22)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50500 entries, 0 to 50499
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Property_ID          50500 non-null  int64
#  1   City                 50500 non-null  str
#  2   Locality             50500 non-null  str
#  3   Property_Type        50500 non-null  str
#  4   BHK                  50500 non-null  int64
#  5   Bathroom             49488 non-null  float64
#  6   Balcony              49488 non-null  float64
#  7   Floor_No             50500 non-null  int64
#  8   Total_Floors         50500 non-null  int64
#  9   Total_Area_in_Sqft   50500 non-null  int64
#  10  Carpet_Area_in_Sqft  50500 non-null  int64
#  11  Parking              50500 non-null  int64
#  12  Furnishing           49491 non-null  str
#  13  Transaction          50500 non-null  str
#  14  Property_Age         50500 non-null  int64
#  15  Facing               49492 non-null  str
# ...

# %%
df.describe()
# Out:
#          Property_ID           BHK      Bathroom       Balcony      Floor_No  \
# count   50500.000000  50500.000000  49488.000000  49488.000000  50500.000000
# mean   124998.002455      2.413822      2.460879      1.117523     15.014436
# std     14438.162760      1.008881      1.159308      0.986056      8.936604
# min    100001.000000      1.000000      1.000000      0.000000      0.000000
# 25%    112485.750000      2.000000      2.000000      0.000000      7.000000
# 50%    124999.500000      2.000000      2.000000      1.000000     15.000000
# 75%    137505.250000      3.000000      3.000000      2.000000     23.000000
# max    150000.000000      5.000000      6.000000      3.000000     30.000000
#
#        Total_Floors  Total_Area_in_Sqft  Carpet_Area_in_Sqft       Parking  \
# count  50500.000000        50500.000000         50500.000000  50500.000000
# mean      22.936594         1650.039149          1336.644733      0.999941
# ...

# %%
df.columns
# Out:
# Index(['Property_ID', 'City', 'Locality', 'Property_Type', 'BHK', 'Bathroom',
#        'Balcony', 'Floor_No', 'Total_Floors', 'Total_Area_in_Sqft',
#        'Carpet_Area_in_Sqft', 'Parking', 'Furnishing', 'Transaction',
#        'Property_Age', 'Facing', 'Lift', 'Gym', 'Power_Backup',
#        'Gated_Community', 'Per_Sqft_Price', 'Total_Amount_Rupees'],
#       dtype='str')

# %%
df.dtypes
# Out:
# Property_ID              int64
# City                       str
# Locality                   str
# Property_Type              str
# BHK                      int64
# Bathroom               float64
# Balcony                float64
# Floor_No                 int64
# Total_Floors             int64
# Total_Area_in_Sqft       int64
# Carpet_Area_in_Sqft      int64
# Parking                  int64
# Furnishing                 str
# Transaction                str
# Property_Age             int64
# Facing                     str
# Lift                       str
# Gym                        str
# Power_Backup               str
# Gated_Community            str
# Per_Sqft_Price         float64
# Total_Amount_Rupees      int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Property_ID               0
# City                      0
# Locality                  0
# Property_Type             0
# BHK                       0
# Bathroom               1012
# Balcony                1012
# Floor_No                  0
# Total_Floors              0
# Total_Area_in_Sqft        0
# Carpet_Area_in_Sqft       0
# Parking                   0
# Furnishing             1009
# Transaction               0
# Property_Age              0
# Facing                 1008
# Lift                      0
# Gym                    1007
# Power_Backup              0
# Gated_Community           0
# Per_Sqft_Price         1008
# Total_Amount_Rupees       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(500)

# %% [markdown]
# Data cleaning

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# Handling Missing values

# %%
#numeric columns
df["Bathroom"].fillna(df["Bathroom"].median(), inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15908\784697072.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["Bathroom"].fillna(df["Bathroom"].median(), inplace=True)
# 0        1.0
# 1        1.0
# 2        2.0
# 3        2.0
# 4        4.0
#         ...
# 49995    1.0
# 49996    2.0
# 49997    2.0
# 49998    2.0
# ...

# %%
#categorical columns
df["Facing"].fillna(df["Facing"].mode()[0], inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15908\3092499064.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["Facing"].fillna(df["Facing"].mode()[0], inplace=True)
# 0        South
# 1        South
# 2        North
# 3        South
# 4        South
#          ...
# 49995    South
# 49996    South
# 49997     East
# ...

# %%
df.isnull().sum()
# Out:
# Property_ID               0
# City                      0
# Locality                  0
# Property_Type             0
# BHK                       0
# Bathroom               1000
# Balcony                1000
# Floor_No                  0
# Total_Floors              0
# Total_Area_in_Sqft        0
# Carpet_Area_in_Sqft       0
# Parking                   0
# Furnishing             1000
# Transaction               0
# Property_Age              0
# Facing                 1000
# Lift                      0
# Gym                    1000
# Power_Backup              0
# Gated_Community           0
# Per_Sqft_Price         1000
# Total_Amount_Rupees       0
# dtype: int64

# %% [markdown]
# Understand price distribution

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(df["Total_Amount_Rupees"])
plt.show()

# %% [markdown]
# Detect outliers

# %%
sns.boxplot(x=df["Total_Amount_Rupees"])
# Out:
# <Axes: xlabel='Total_Amount_Rupees'>

# %% [markdown]
# Identify which numerical features are most related to house price.

# %%
plt.figure(figsize=(12,8))

sns.heatmap(
    df.corr(numeric_only=True),
    annot=True,
    cmap="coolwarm"
)

plt.show()

# %% [markdown]
# Visualize how house area affects price

# %%
sns.scatterplot(
    data=df,
    x="Total_Area_in_Sqft",
    y="Total_Amount_Rupees"
)
# Out:
# <Axes: xlabel='Total_Area_in_Sqft', ylabel='Total_Amount_Rupees'>

# %% [markdown]
# See how many properties come from each city

# %%
sns.countplot(data=df,x="City")
# Out:
# <Axes: xlabel='City', ylabel='count'>

# %% [markdown]
# Feature Engineering

# %%
df.columns
# Out:
# Index(['Property_ID', 'City', 'Locality', 'Property_Type', 'BHK', 'Bathroom',
#        'Balcony', 'Floor_No', 'Total_Floors', 'Total_Area_in_Sqft',
#        'Carpet_Area_in_Sqft', 'Parking', 'Furnishing', 'Transaction',
#        'Property_Age', 'Facing', 'Lift', 'Gym', 'Power_Backup',
#        'Gated_Community', 'Per_Sqft_Price', 'Total_Amount_Rupees'],
#       dtype='str')

# %%
df = df.drop("Property_ID", axis=1)

# %%
categorical_columns = df.select_dtypes(include="object").columns

for col in categorical_columns:
    print(f"\n{col}")
    print(df[col].value_counts())
# Out:
# City
# City
# Pune         8433
# Bangalore    8380
# Delhi        8322
# Chennai      8316
# Hyderabad    8315
# Mumbai       8234
# Name: count, dtype: int64
#
# Locality
# Locality
# Hadapsar           1790
# Porur              1744
# Borivali           1723
# Wakad              1717
# Yelahanka          1704
# Electronic City    1703
# HSR Layout         1701
# Kondapur           1696
# Saket              1686
# Uttam Nagar        1676
# Miyapur            1673
# Whitefield         1670
# Dwarka             1665
# Velachery          1657
# Janakpuri          1656
# Andheri            1654
# Kukatpally         1653
# Gachibowli         1653
# OMR                1649
# Baner              1648
# Anna Nagar         1647
# Hinjewadi          1645
# Madhapur           1640
# Rohini             1639
# Kharadi            1633
# Navi Mumbai        1626
# Tambaram           1619
# Thane              1619
# Powai              1612
# JP Nagar           1602
# Name: count, dtype: int64
#
# ...

# %%
df["Area_per_BHK"] = df["Total_Area_in_Sqft"] / df["BHK"]

# %%
df["Carpet_Ratio"] = (
    df["Carpet_Area_in_Sqft"] /
    df["Total_Area_in_Sqft"]
)

# %%
df["Floor_Ratio"] = (
    df["Floor_No"] /
    df["Total_Floors"]
)

# %% [markdown]
# Data Preprocessing

# %%
import numpy as np

# Remove Property_ID (not useful for prediction)
df = df.drop(columns=["Property_ID"], errors="ignore")

# Replace infinite values with NaN
df.replace([np.inf, -np.inf], np.nan, inplace=True)

# Check missing values
print(df.isnull().sum())
# Out:
# City                      0
# Locality                  0
# Property_Type             0
# BHK                       0
# Bathroom               1000
# Balcony                1000
# Floor_No                  0
# Total_Floors              0
# Total_Area_in_Sqft        0
# Carpet_Area_in_Sqft       0
# Parking                   0
# Furnishing             1000
# Transaction               0
# Property_Age              0
# Facing                 1000
# Lift                      0
# Gym                    1000
# Power_Backup              0
# Gated_Community           0
# Per_Sqft_Price         1000
# Total_Amount_Rupees       0
# Area_per_BHK              0
# Carpet_Ratio              0
# Floor_Ratio               0
# dtype: int64

# %%
features = [
    "City",
    "Property_Type",
    "BHK",
    "Bathroom",
    "Parking",
    "Total_Area_in_Sqft"
]

X = df[features]
y = df["Total_Amount_Rupees"]

# %%
categorical_features = X.select_dtypes(include=["object"]).columns

numerical_features = X.select_dtypes(include=["int64", "float64"]).columns

print("Categorical Features:")
print(categorical_features)

print("\nNumerical Features:")
print(numerical_features)
# Out:
# Categorical Features:
# Index(['City', 'Property_Type'], dtype='str')
#
# Numerical Features:
# Index(['BHK', 'Bathroom', 'Parking', 'Total_Area_in_Sqft'], dtype='str')
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15908\1090997043.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_features = X.select_dtypes(include=["object"]).columns

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

# %%
numeric_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy="median"))
])

# %%
categorical_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("encoder", OneHotEncoder(handle_unknown="ignore"))
])

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_pipeline, numerical_features),
        ("cat", categorical_pipeline, categorical_features)
    ]
)

# %%
X_train_processed = preprocessor.fit_transform(X_train)

X_test_processed = preprocessor.transform(X_test)

# %%
import numpy as np

X_train_dense = X_train_processed.toarray() if hasattr(X_train_processed, "toarray") else X_train_processed

print("Total NaN values:", np.isnan(X_train_dense).sum())
# Out:
# Total NaN values: 0

# %% [markdown]
# MODEL BUILDING

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor

from sklearn.metrics import (
    r2_score,
    mean_absolute_error,
    mean_squared_error
)

# %%
import pandas as pd
import numpy as np

models = {
    "Linear Regression": LinearRegression(),
    "Decision Tree": DecisionTreeRegressor(random_state=42),
    "Random Forest": RandomForestRegressor(random_state=42),
    "Gradient Boosting": GradientBoostingRegressor(random_state=42),
    "Extra Trees": ExtraTreesRegressor(random_state=42)
}

# %%
results = []

for name, model in models.items():

    model.fit(X_train_processed, y_train)

    y_pred = model.predict(X_test_processed)

    r2 = r2_score(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)

    results.append({
        "Model": name,
        "R2 Score": r2,
        "MAE": mae,
        "MSE": mse,
        "RMSE": rmse
    })

results_df = pd.DataFrame(results)

results_df.sort_values(
    by="R2 Score",
    ascending=False
)
# Out:
#                Model  R2 Score           MAE           MSE          RMSE
# 0  Linear Regression  0.524665  6.239567e+06  6.405917e+13  8.003697e+06
# 3  Gradient Boosting  0.519972  6.253066e+06  6.469153e+13  8.043105e+06
# 2      Random Forest  0.429416  6.681276e+06  7.689550e+13  8.769008e+06
# 4        Extra Trees  0.282379  7.317269e+06  9.671117e+13  9.834184e+06
# 1      Decision Tree  0.043997  8.294697e+06  1.288370e+14  1.135064e+07

# %% [markdown]
# HYPERPARAMETER TUNING

# %%
results_df.sort_values(by="R2 Score", ascending=False)
# Out:
#                Model  R2 Score           MAE           MSE          RMSE
# 0  Linear Regression  0.524665  6.239567e+06  6.405917e+13  8.003697e+06
# 3  Gradient Boosting  0.519972  6.253066e+06  6.469153e+13  8.043105e+06
# 2      Random Forest  0.429416  6.681276e+06  7.689550e+13  8.769008e+06
# 4        Extra Trees  0.282379  7.317269e+06  9.671117e+13  9.834184e+06
# 1      Decision Tree  0.043997  8.294697e+06  1.288370e+14  1.135064e+07

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(random_state=42)

# %%
param_grid = {
    "n_estimators": [100, 200, 300],

    "max_depth": [10, 20, 30, None],

    "min_samples_split": [2, 5, 10],

    "min_samples_leaf": [1, 2, 4],

    "max_features": ["sqrt", "log2"]
}

# %%
random_search = RandomizedSearchCV(
    estimator=rf,

    param_distributions=param_grid,

    n_iter=20,

    scoring="r2",

    cv=5,

    verbose=2,

    random_state=42,

    n_jobs=-1
)

# %%
random_search.fit(
    X_train_processed,
    y_train
)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(random_state=42),
#                    n_iter=20, n_jobs=-1,
#                    param_distributions={'max_depth': [10, 20, 30, None],
#                                         'max_features': ['sqrt', 'log2'],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [100, 200, 300]},
#                    random_state=42, scoring='r2', verbose=2)

# %%
print(random_search.best_params_)
# Out:
# {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 10}

# %%
print(random_search.best_score_)
# Out:
# 0.5117217271963745

# %%
best_model = random_search.best_estimator_

# %%
y_pred = best_model.predict(
    X_test_processed
)

# %%
from sklearn.metrics import (
    r2_score,
    mean_absolute_error,
    mean_squared_error
)

import numpy as np

# %%
r2 = r2_score(y_test, y_pred)

mae = mean_absolute_error(y_test, y_pred)

mse = mean_squared_error(y_test, y_pred)

rmse = np.sqrt(mse)

print("R2 :", r2)

print("MAE :", mae)

print("MSE :", mse)

print("RMSE :", rmse)
# Out:
# R2 : 0.5129853119250858
# MAE : 6291635.52512757
# MSE : 65633163490347.84
# RMSE : 8101429.718904425

# %%
#Compare before and after 
comparison = pd.DataFrame({
    "Metric": ["R2", "MAE", "MSE", "RMSE"],

    "Before": [
        results_df.iloc[0]["R2 Score"],
        results_df.iloc[0]["MAE"],
        results_df.iloc[0]["MSE"],
        results_df.iloc[0]["RMSE"]
    ],

    "After": [
        r2,
        mae,
        mse,
        rmse
    ]
})

comparison
# Out:
#   Metric        Before         After
# 0     R2  5.246647e-01  5.129853e-01
# 1    MAE  6.239567e+06  6.291636e+06
# 2    MSE  6.405917e+13  6.563316e+13
# 3   RMSE  8.003697e+06  8.101430e+06

# %%
import joblib
import os

os.makedirs("models", exist_ok=True)

# %%
joblib.dump(preprocessor, "models/preprocessor.pkl")
joblib.dump(model, "models/house_price_model.pkl")

print("Saved successfully!")
# Out:
# Saved successfully!

# %%
import os

print(os.listdir("models"))
# Out:
# ['house_price_model.pkl', 'preprocessor.pkl']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
plt.scatter(y_test, y_pred, alpha=0.5)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual vs Predicted House Prices")

# Reference line
min_val = min(y_test.min(), y_pred.min())
max_val = max(y_test.max(), y_pred.max())
plt.plot([min_val, max_val], [min_val, max_val], "r--")

plt.show()

# %% [markdown]
# This plot helps you visually assess how close your predictions are to the true values
